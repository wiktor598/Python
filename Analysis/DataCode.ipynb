# %%
import pandas as pd

Data = pd.read_csv('people.csv', encoding='utf-8')  #contents of people.csv is read via pandas and assigned to dataframe

        #query to count SOAccount responce in percentage, if you remove "(normalize=True) * 100" it will display the response in numbers
 #Data['SOAccount'].value_counts(normalize=True) * 100
        #


        # instruction that tells Jupyter Notebook to display charts inline
# %matplotlib inline 
        #


        # .plot() takes the input from OPSys and plots it, (kind = "bar") plots it on a bar chart
Data['OpSys'].value_counts().plot(kind="bar", figsize=(4,2), color="#61d199")
        # figsize arg adjusts the size of the diagram and color arg adjusts the color of the bars


        # Pulls from DF "Data" from SOAccount column of which the answer was no and stores in  a new dataframe called said_no 
said_no = Data[Data['SOAccount'] == 'No']
said_no.head(2)       
        #   head(2) shows the top 2 respondents in the dataframe said_no.
# Out:
#     ResponseId                      MainBranch          Employment   Country  \
# 40          41  I am a developer by profession  Employed full-time  Portugal
# 44          45  I am a developer by profession  Employed full-time    France
#
#    US_State UK_Country                                          EdLevel  \
# 40      NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44      NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#        Age1stCode LearnCode         YearsCode  ...              Age Gender  \
# 40  18 - 24 years    School  Less than 1 year  ...  25-34 years old    Man
# 44  18 - 24 years    School                 6  ...  18-24 years old  Woman
#
#    Trans                Sexuality                     Ethnicity  \
# 40    No                      NaN                           NaN
# 44    No  Straight / Heterosexual  White or of European descent
#
#         Accessibility       MentalHealth           SurveyLength  \
# ...
